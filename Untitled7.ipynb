# %%
from django.db import connection, reset_queries
from registros.models import LOTE,LOTE_DET
import time

start_time = time.time()

lista = LOTE_DET.objects.all().prefetch_related()
for l in lista:
   lote_lote = l.lode_lote 



print (lista.query)

end_time=time.time()
duration=(end_time - start_time)
print(f'Executou um total de {len(connection.queries)}Queries')
print(f'Tempo de Execuçao {round(duration, 3)}Segundos')
reset_queries()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\fields\related_descriptors.py in __get__(self, instance, cls)
#     172         try:
# --> 173             rel_obj = self.field.get_cached_value(instance)
#     174         except KeyError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\fields\mixins.py in get_cached_value(self, instance, default)
#      14         try:
# ---> 15             return instance._state.fields_cache[cache_name]
#      16         except KeyError:
#
# KeyError: 'lode_lote'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-690ebc245058> in <module>
#       7 lista = LOTE_DET.objects.all().prefetch_related()
#       8 for l in lista:
# ----> 9    lote_lote = l.lode_lote
#      10
#      11
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\fields\related_descriptors.py in __get__(self, instance, cls)
#     185                 rel_obj = None
#     186             if rel_obj is None and has_value:
# --> 187                 rel_obj = self.get_object(instance)
#     188                 remote_field = self.field.remote_field
#     189                 # If this is a one-to-one relation, set the reverse accessor
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\fields\related_descriptors.py in get_object(self, instance)
#     152         qs = self.get_queryset(instance=instance)
#     153         # Assuming the database enforces foreign keys, this won't fail.
# --> 154         return qs.get(self.field.get_reverse_related_filter(instance))
#     155
#     156     def __get__(self, instance, cls=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\query.py in get(self, *args, **kwargs)
#     429             limit = MAX_GET_RESULTS
#     430             clone.query.set_limits(high=limit)
# --> 431         num = len(clone)
#     432         if num == 1:
#     433             return clone._result_cache[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\query.py in __len__(self)
#     260
#     261     def __len__(self):
# --> 262         self._fetch_all()
#     263         return len(self._result_cache)
#     264
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\query.py in _fetch_all(self)
#    1322     def _fetch_all(self):
#    1323         if self._result_cache is None:
# -> 1324             self._result_cache = list(self._iterable_class(self))
#    1325         if self._prefetch_related_lookups and not self._prefetch_done:
#    1326             self._prefetch_related_objects()
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\query.py in __iter__(self)
#      49         # Execute the query. This will also fill compiler.select, klass_info,
#      50         # and annotations.
# ---> 51         results = compiler.execute_sql(chunked_fetch=self.chunked_fetch, chunk_size=self.chunk_size)
#      52         select, klass_info, annotation_col_map = (compiler.select, compiler.klass_info,
#      53                                                   compiler.annotation_col_map)
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\models\sql\compiler.py in execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1173             cursor = self.connection.cursor()
#    1174         try:
# -> 1175             cursor.execute(sql, params)
#    1176         except Exception:
#    1177             # Might fail for server-side cursors (e.g. connection closed)
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      96     def execute(self, sql, params=None):
#      97         with self.debug_sql(sql, params, use_last_executed_query=True):
# ---> 98             return super().execute(sql, params)
#      99
#     100     def executemany(self, sql, param_list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      64
#      65     def execute(self, sql, params=None):
# ---> 66         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      67
#      68     def executemany(self, sql, param_list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\backends\utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      73         for wrapper in reversed(self.db.execute_wrappers):
#      74             executor = functools.partial(wrapper, executor)
# ---> 75         return executor(sql, params, many, context)
#      76
#      77     def _execute(self, sql, params, *ignored_wrapper_args):
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\backends\sqlite3\base.py in execute(self, query, params)
#     421             return Database.Cursor.execute(self, query)
#     422         query = self.convert_query(query)
# --> 423         return Database.Cursor.execute(self, query, params)
#     424
#     425     def executemany(self, query, param_list):
#
# KeyboardInterrupt:
